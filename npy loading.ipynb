# %%
import numpy as np
l=np.load("mask.npy")

# %%
l
# Out:
# array([[[[ 80, 151, 149],
#          [ 81, 154, 152],
#          [ 83, 152, 149],
#          ...,
#          [112, 174, 179],
#          [115, 175, 181],
#          [110, 172, 178]],
#
#         [[ 82, 151, 153],
#          [ 86, 152, 153],
#          [ 79, 150, 152],
#          ...,
#          [113, 170, 179],
#          [111, 171, 180],
#          [107, 170, 178]],
#
#         [[ 80, 150, 147],
#          [ 80, 148, 144],
#          [ 70, 145, 148],
#          ...,
#          [116, 171, 174],
#          [118, 175, 183],
#          [114, 173, 180]],
#
#         ...,
#
#         [[115,  99,  83],
#          [112,  97,  79],
#          [114,  98,  77],
#          ...,
#          [197, 199, 198],
#          [174, 173, 180],
#          [ 40,  47,  68]],
#
#         [[110,  94,  84],
#          [108,  95,  84],
#          [114, 100,  91],
#          ...,
#          [201, 205, 200],
#          [195, 202, 198],
#          [183, 190, 190]],
#
#         [[124, 117, 114],
# ...

# %%
l1=np.load("without_mask.npy")

# %% [markdown]
#  l1

# %%
l1
# Out:
# array([[[[220,   3, 220],
#          [164,   8, 167],
#          [162,   5, 165],
#          ...,
#          [181,  21, 177],
#          [185,  28, 179],
#          [189,  34, 186]],
#
#         [[164,   9, 167],
#          [ 23,  24,  33],
#          [ 22,  18,  25],
#          ...,
#          [ 56,  53,  53],
#          [ 70,  69,  61],
#          [ 89,  92,  81]],
#
#         [[163,   7, 167],
#          [ 24,  25,  31],
#          [ 28,  29,  34],
#          ...,
#          [ 40,  42,  42],
#          [ 78,  77,  73],
#          [ 89,  84,  74]],
#
#         ...,
#
#         [[173,  16, 169],
#          [ 54,  46,  40],
#          [122, 116, 114],
#          ...,
#          [184, 146, 144],
#          [165, 140, 127],
#          [255, 255, 250]],
#
#         [[174,  15, 169],
#          [ 54,  46,  44],
#          [118, 115, 115],
#          ...,
#          [247, 213, 225],
#          [179, 156, 154],
#          [255, 255, 252]],
#
#         [[179,  20, 175],
# ...
